# %%
#Completed
# Google API integration - extract data from spreadsheet
# Map configuration & icons
# Push to website (hosted on BlueHost) automatically
# Secure storage of file without exposure to blog
# Run the script Online in a cron format

#TODO:
# Integrating code with matching algorithm & writing matched entry into spreadsheet

# %%
#Basic
from __future__ import print_function
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point
import datetime as dt

#Google Docs integration
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

#File Transfer
import ftplib
import os

from connections import connections
from map_generator import public_map,private_map
from settings import *

from database_entry import add_volunteers_to_db
from connections import connections

# %%
# The ID and range of a sample spreadsheet.
volunteer_sheet_data = [{'source':'GreenDream','sheet_id':'1e9H5yO1COGLNfA3lyZxRSgc2llDKRSFZX92Ov8VOzOs','range':'Form Responses 1!A1:K1000','columns': {'Timestamp':'timestamp', 'Full Name':'name', 'WhatsApp Contact Number':'mob_number', 'Email Address':'email_id',
       'Your Location (Prefer mentioning nearest Google Maps Landmark - that you specify on mobile apps like Ola, Uber and Swiggy)':'address',
       'Do you have a grocery and medical store within walking distance of 500 meters?':'grocery_store',
       'GeoStamp':'geostamp', 'GeoAddress':'geoaddress', 'GeoCodeLat':'latitude', 'GeoCodeLon':'longitude'}}]
senior_citizen_sheet_data = [{'source':'GreenDream','sheet_id':'1KrZCG_fYvImIy_-549VB0rzbbfKHkkbmJG0l6DH01zM','range':'Form Responses 1!A1:K1000','columns':{'Timestamp':'timestamp', 'Full Name':'name', 'Mobile Number':'mob_number', 'Age':'age',
       'Your Location (be as precise as possible)':'address',
       'Would you like to give any special instructions to the volunteer aligned to you? Please share below.':'request',
       'Task Status':'status', 'GeoStamp':'geostamp', 'GeoAddress':'geoaddress','GeoCodeLat':'latitude', 'GeoCodeLon':'longitude'}}]

public_file_name= 'output/COVID_SOS_v0.html'
private_file_name= 'output/private_COVID_SOS_v0.html'

# %%
def google_api_activation():
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('support_files/token.pickle'):
        with open('support_files/token.pickle', 'rb') as token1:
            creds = pickle.load(token1)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('support_files/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('support_files/token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    service = build('sheets', 'v4', credentials=creds)
    return service

def extract_all_sheets(service,sheets_dict):
    sheets_df=pd.DataFrame()
    for i in sheets_dict:
        source = i['source']
        sheet_id=i['sheet_id']
        range_name=i['range']
        column_rename=i['columns']
        sheets_df_x = sheet_header(extract_sheet(service,sheet_id,range_name),source)
        sheets_df_x = sheets_df_x.rename(columns=column_rename)
        sheets_df = sheets_df.append(sheets_df_x)
    return sheets_df

def extract_sheet(service,sheet_id,range_name):
    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=sheet_id,range=range_name).execute()
    return result

def sheet_header(df,source):
    input_data = pd.DataFrame(df['values'])
    new_header = input_data.iloc[0] #grab the first row for the header
    input_data = input_data[1:] #take the data less the header row
    input_data.columns = new_header #
    input_data['source']=source
    input_data = input_data.reset_index(drop=True)
    return input_data


def sheet_clean_up(df,default_r,buffer_radius,user_type='volunteer'):
    # Sample Data
    df = gpd.GeoDataFrame(df)
    print('Received ', df.shape[0], ' responses')
    d = mob_number_clean_up(df[['mob_number']])
    df['mob_number']=d['mob_number']
    df = df[d['mob_number_correct']]
    print('Received ', d[d['mob_number_correct']==False].shape[0], ' responses with incorrect mobile numbers')
    df['latitude']=df['latitude'].astype(float).fillna(0)
    df['longitude']=df['longitude'].astype(float).fillna(0)
    print('Received ', df[(df['latitude']==0)|(df['longitude']==0)].shape[0], ' responses with no location')
    df['radius']=default_r
    geometry = df.apply(lambda x: Point(x['longitude'],x['latitude']).buffer(buffer_radius*x.radius),axis=1)
    crs = {'init': 'epsg:4326'}
    f_df = gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
    if(user_type=='volunteer'):
#         f_df['timestamp'] = pd.to_datetime(f_df['timestamp'])
        f_df['icon']='location'
        f_df['country']='India'
    if(user_type=='requests'):
        f_df['icon']='home'
        f_df['country']='India'
        f_df['email_id']=''
    return f_df


def mob_number_clean_up(df):
    #Has space
    df['mob_number']=df['mob_number'].str.replace(" ",'')
    df['mob_number']=df['mob_number'].str.replace(",",'')
    df['mob_number']=df['mob_number'].str.replace("\+91",'')
    df['mob_number']=df['mob_number'].apply(lambda x: str(int(x)))
    #Has zero
    df['mob_number_correct']=df['mob_number'].apply(lambda x: len(str(int(x)))==10)    
    return df

# %%
def push_file_to_server(File2Send,Url2Store):
    ftp = connections('ftp')
    Output_Directory = "/public_html/covid19/"
    ftp.cwd(Output_Directory)
    with open(File2Send, "rb") as server_f:
        ftp.storbinary('STOR ' + os.path.basename(Url2Store), server_f)
    print('File saved to server at URL: www.thebangaloreguy.com/covid19/'+(Url2Store).split('/')[-1])
    return None

# %%
def main():
    #Fetching Data from sheets
    print('Running script at',dt.datetime.utcnow()+dt.timedelta(minutes=330))
    service = google_api_activation()
    print('Google Authentication completed')
    volunteer_df = extract_all_sheets(service,volunteer_sheet_data)
    volunteer_df['TYPE']='VOLUNTEER'
    requests_df = extract_all_sheets(service,senior_citizen_sheet_data)
    requests_df['TYPE']='REQUEST'
    
    v_df = sheet_clean_up(volunteer_df,default_r,buffer_radius,'volunteer')
    v_db_status, response = add_volunteers_to_db(v_df)
    print('DB Update Status: ', v_db_status)
    print('Message:', response)
    r_df = sheet_clean_up(requests_df,default_r,buffer_radius,'requests')
    #add_requests(r_df.rename(columns={'email_d':'email_id'})[['timestamp', 'name', 'mob_number', 'email_id', 'country', 'address', 'geoaddress', 'latitude', 'longitude', 'source', 'request', 'age']])
    private_map_v1 = private_map(v_df,r_df,private_file_name,map_pkg='kepler')
    push_file_to_server(private_file_name,private_file_name)
    push_file_to_server(private_file_name,'output/share_and_survive_v0_dark.html')
    public_map_v1 = public_map(v_df,r_df,public_file_name,map_pkg='kepler')
    push_file_to_server(public_file_name,public_file_name)
    #Processing Data
    return v_df, r_df, private_map_v1,public_map_v1

# %%
v_df, r_df, p1,p2=main()
# Out:
# Running script at 2020-03-30 21:04:22.158560
# Google Authentication completed
# Received  142  responses
# Received  2  responses with incorrect mobile numbers
# Received  27  responses with no location
# C:\Users\sid\anaconda3\envs\project_covid19\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sid\anaconda3\envs\project_covid19\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sid\anaconda3\envs\project_covid19\lib\site-packages\ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sid\anaconda3\envs\project_covid19\lib\site-packages\ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\sid\anaconda3\envs\project_covid19\lib\site-packages\ipykernel_launcher.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# DB Update Status:  True
# Message: Volunteer already exists. No New Volunteers to be added
# Received  46  responses
# Received  0  responses with incorrect mobile numbers
# Received  19  responses with no location
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md
# The private Map contains  113  volunteers and  25  pending requests
# Map saved to output/private_COVID_SOS_v0.html!
# File saved to server at URL: www.thebangaloreguy.com/covid19/private_COVID_SOS_v0.html
# File saved to server at URL: www.thebangaloreguy.com/covid19/share_and_survive_v0_dark.html
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md
# The public map contains  113  volunteers and  27  pending requests
# Map saved to output/COVID_SOS_v0.html!
# File saved to server at URL: www.thebangaloreguy.com/covid19/COVID_SOS_v0.html

# %%
pd.DataFrame(v_df[['timestamp', 'name','latitude','longitude','radius','icon','TYPE']]).to_dict('records')
# Out:
# [{'timestamp': '3/24/2020 13:26:29',
#   'name': 'Ashish sen',
#   'latitude': 26.8503054,
#   'longitude': 75.8003968,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:27:28',
#   'name': 'Mayur Kumar',
#   'latitude': 28.6406168,
#   'longitude': 77.0568883,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:28:12',
#   'name': 'Dhvani Mehta',
#   'latitude': 28.5722579,
#   'longitude': 77.2232168,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:29:51',
#   'name': 'Tulika Gupta',
#   'latitude': 28.4430645,
#   'longitude': 77.0965348,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:34:55',
#   'name': 'Ankita Gupta',
#   'latitude': 28.4430645,
#   'longitude': 77.0965348,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:35:33',
#   'name': 'Aquil Matten',
#   'latitude': 20.4643505,
#   'longitude': 85.8534391,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:35:35',
#   'name': 'Fahmin Hussain ',
#   'latitude': 18.4524618,
#   'longitude': 73.9001803,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:36:47',
#   'name': 'Aquil Matten',
#   'latitude': 20.4643505,
#   'longitude': 85.8534391,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:42:48',
#   'name': 'Jitender Singh',
#   'latitude': 26.8896255,
#   'longitude': 75.7146418,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:46:01',
#   'name': 'Jyoti Gupta ',
#   'latitude': 12.9286417,
#   'longitude': 77.6203729,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:56:16',
#   'name': 'Arjun Adlakha',
#   'latitude': 28.6387293,
#   'longitude': 77.0853702,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:57:05',
#   'name': 'Mankirat Singh',
#   'latitude': 28.6387293,
#   'longitude': 77.0853702,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:57:59',
#   'name': 'SANJAY MATHUR',
#   'latitude': 28.5259388,
#   'longitude': 77.1437485,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 13:59:04',
#   'name': 'Shushant Pradhan ',
#   'latitude': 28.6760102,
#   'longitude': 77.1710018,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:00:18',
#   'name': 'Ruchi Gandhi Chawla',
#   'latitude': 28.4803382,
#   'longitude': 77.0155289,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:02:09',
#   'name': 'Aradhana bhalla ',
#   'latitude': 28.5741308,
#   'longitude': 77.1573859,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:09:23',
#   'name': 'Akhil Anilkumar',
#   'latitude': 28.5946482,
#   'longitude': 77.0334456,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:10:37',
#   'name': 'Monika dhingra',
#   'latitude': 28.5861466,
#   'longitude': 77.0330021,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:22:02',
#   'name': 'Shailesh Choudhary',
#   'latitude': 23.6676092,
#   'longitude': 86.049081,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:27:45',
#   'name': 'AMIT PRASAD',
#   'latitude': 26.1704902,
#   'longitude': 91.7359235,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:42:06',
#   'name': 'Kashif khan',
#   'latitude': 28.5112658,
#   'longitude': 77.3893264,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:45:42',
#   'name': 'Shubham bhamu',
#   'latitude': 26.8967019,
#   'longitude': 75.8186028,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:47:30',
#   'name': 'Anshul Malhotra',
#   'latitude': 28.3980466,
#   'longitude': 77.2664697,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:48:17',
#   'name': 'Akash Sehgal',
#   'latitude': 28.6500782,
#   'longitude': 77.2867115,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:48:36',
#   'name': 'ridhima kandru',
#   'latitude': 28.4362903,
#   'longitude': 77.1315915,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:54:04',
#   'name': 'Vikash Yadav',
#   'latitude': 25.5412536,
#   'longitude': 82.3093392,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 14:59:08',
#   'name': 'Nikhil Kad',
#   'latitude': 28.6162092,
#   'longitude': 77.0559583,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:09:51',
#   'name': 'Kapil Singh',
#   'latitude': 27.3868934,
#   'longitude': 80.104009,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:13:06',
#   'name': 'Arun Soni',
#   'latitude': 26.8903995,
#   'longitude': 75.7287249,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:28:50',
#   'name': 'Karan Patel',
#   'latitude': 12.9385608,
#   'longitude': 77.550964,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:46:43',
#   'name': 'Subhojit Bhattacharya',
#   'latitude': 28.4653348,
#   'longitude': 77.5325986,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:48:37',
#   'name': 'Gaurav Agarwal',
#   'latitude': 28.5856166,
#   'longitude': 77.3990924,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:51:56',
#   'name': 'Yukti Ballani ',
#   'latitude': 28.4178854,
#   'longitude': 77.0425298,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:57:24',
#   'name': 'Suparna Anand',
#   'latitude': 28.5058742,
#   'longitude': 77.2049389,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 15:59:37',
#   'name': 'Subhojit Bhattacharya',
#   'latitude': 28.4653348,
#   'longitude': 77.5325986,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 16:09:23',
#   'name': 'Dr Ajay Pandya',
#   'latitude': 23.7500448,
#   'longitude': 86.7013776,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 16:12:39',
#   'name': 'Shikha Gupta',
#   'latitude': 28.628993,
#   'longitude': 77.1391372,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 16:19:06',
#   'name': 'Prashant Gupta',
#   'latitude': 19.1326828,
#   'longitude': 72.7973377,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 16:33:50',
#   'name': 'Eshita Arora',
#   'latitude': 28.6212291,
#   'longitude': 77.0204836,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 16:38:19',
#   'name': 'Mital Mehta',
#   'latitude': 18.6028473,
#   'longitude': 73.7679464,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 18:26:39',
#   'name': 'Somnath saha ',
#   'latitude': 28.5856166,
#   'longitude': 77.3990924,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 18:38:47',
#   'name': 'Manan Tholia',
#   'latitude': 26.8530258,
#   'longitude': 75.8024801,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 18:46:11',
#   'name': 'Shivangi Kashyap',
#   'latitude': 28.5284626,
#   'longitude': 77.2525777,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 18:46:27',
#   'name': 'Mohit kumawat',
#   'latitude': 26.878144,
#   'longitude': 75.7948481,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 19:09:51',
#   'name': 'deepika gupta',
#   'latitude': 28.6019349,
#   'longitude': 77.3468111,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 19:12:26',
#   'name': 'Ajeesh Raju',
#   'latitude': 26.8404724,
#   'longitude': 75.8037058,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 19:36:25',
#   'name': 'Krunal Sarode ',
#   'latitude': 18.5439769,
#   'longitude': 73.8762987,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 20:31:52',
#   'name': 'AMAN BATTA',
#   'latitude': 28.5639081,
#   'longitude': 77.2112917,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 20:37:41',
#   'name': 'Rajeshwar Butalia',
#   'latitude': 28.4147193,
#   'longitude': 77.0429407,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 20:55:32',
#   'name': 'Manjot Singh',
#   'latitude': 28.4446441,
#   'longitude': 77.463566,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 21:00:18',
#   'name': 'ridhima kandru',
#   'latitude': 28.4362903,
#   'longitude': 77.1315915,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 21:16:59',
#   'name': 'Gulshan bhagat',
#   'latitude': 32.3827904,
#   'longitude': 75.4926629,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 21:55:59',
#   'name': 'Siddhant Nesarikar',
#   'latitude': 19.1082422,
#   'longitude': 72.8404093,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 22:14:17',
#   'name': 'Jessy',
#   'latitude': 28.6201891,
#   'longitude': 77.342835,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 22:55:09',
#   'name': 'Gagandeep ',
#   'latitude': 32.7027027,
#   'longitude': 74.8571099,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:01:24',
#   'name': 'Aditya Sk',
#   'latitude': 17.4776922,
#   'longitude': 78.4963519,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:04:51',
#   'name': 'Shubham Bhardwaj',
#   'latitude': 29.4781969,
#   'longitude': 77.7028093,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:39:47',
#   'name': 'Meenakshi Bhujwala',
#   'latitude': 28.5374194,
#   'longitude': 77.2368121,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:40:05',
#   'name': 'Kuldeep nagal',
#   'latitude': 26.920197,
#   'longitude': 75.6681013,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:45:31',
#   'name': 'Ipshita moitra',
#   'latitude': 28.5334468,
#   'longitude': 77.1420857,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:54:59',
#   'name': 'Bhushan nariani',
#   'latitude': 28.526505,
#   'longitude': 77.1500712,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/24/2020 23:59:16',
#   'name': 'Anna Mehra ',
#   'latitude': 28.5112705,
#   'longitude': 77.3893264,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 0:54:56',
#   'name': 'Udit Thukral',
#   'latitude': 28.8859676,
#   'longitude': 78.7281912,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 1:15:05',
#   'name': 'Ashutosh kumar',
#   'latitude': 28.6059747,
#   'longitude': 77.2949314,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 1:55:10',
#   'name': 'Kavita Mongia',
#   'latitude': 28.553292,
#   'longitude': 77.2041906,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 3:41:12',
#   'name': 'Bharti Singhla',
#   'latitude': 28.4449592,
#   'longitude': 77.0785492,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 7:23:50',
#   'name': 'Nishith Pandey',
#   'latitude': 28.5112705,
#   'longitude': 77.3893264,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 8:57:29',
#   'name': 'Shubhi jaiswar',
#   'latitude': 29.9637637,
#   'longitude': 77.486386,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 9:56:20',
#   'name': 'Anubha Khandelwal',
#   'latitude': 26.9056648,
#   'longitude': 75.7365053,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 10:17:08',
#   'name': 'Mohit raj Bansal',
#   'latitude': 26.9040218,
#   'longitude': 75.7449244,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 12:12:12',
#   'name': 'Grashmi ',
#   'latitude': 28.457071,
#   'longitude': 77.0465272,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 12:12:55',
#   'name': 'Satyaprakash meena',
#   'latitude': 26.8503437,
#   'longitude': 75.8003967,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 12:42:31',
#   'name': 'Anoop Pant',
#   'latitude': 28.6395358,
#   'longitude': 77.3721549,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 13:36:04',
#   'name': 'Vikram R Srihari',
#   'latitude': 28.5717376,
#   'longitude': 77.1726272,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 13:58:16',
#   'name': 'atul tanksale',
#   'latitude': 18.4947783,
#   'longitude': 73.8308307,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 16:01:21',
#   'name': 'Deepty',
#   'latitude': 28.5406262,
#   'longitude': 77.2319449,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 16:20:39',
#   'name': 'Bhanvi',
#   'latitude': 28.6504889,
#   'longitude': 77.1239958,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 17:37:10',
#   'name': 'SUMITA Roy',
#   'latitude': 28.4484223,
#   'longitude': 77.0940524,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 17:50:13',
#   'name': 'Karun Jhangiani',
#   'latitude': 19.1950422,
#   'longitude': 72.8306222,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 18:26:25',
#   'name': 'Shiv Shakti Vashishtha',
#   'latitude': 28.5875317,
#   'longitude': 77.3841197,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 20:53:16',
#   'name': 'Neha Goel ',
#   'latitude': 28.5605072,
#   'longitude': 77.1585414,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 21:03:15',
#   'name': 'Vinita kumari',
#   'latitude': 28.4434945,
#   'longitude': 77.0796919,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 21:21:49',
#   'name': 'Richa Verma',
#   'latitude': 25.6173625,
#   'longitude': 85.1475943,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 21:31:18',
#   'name': 'Monika Agarwal',
#   'latitude': 28.4300094,
#   'longitude': 77.0930076,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/25/2020 22:25:04',
#   'name': 'Arpita Chatterjee',
#   'latitude': 28.5418837,
#   'longitude': 77.2080635,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 9:08:51',
#   'name': 'Parul Kumar',
#   'latitude': 28.6015094,
#   'longitude': 77.1837893,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 9:11:54',
#   'name': 'Pavithra Lakshmanan',
#   'latitude': 19.085874,
#   'longitude': 72.8269116,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 11:09:44',
#   'name': 'Mushfiq Sarfaraz Yasin',
#   'latitude': 28.49067257,
#   'longitude': 77.09265078,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 11:21:47',
#   'name': 'Tushar Batham',
#   'latitude': 18.5195738,
#   'longitude': 73.7678122,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 11:53:17',
#   'name': 'GIRISH CHHATWAL',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 12:53:08',
#   'name': 'Tarun Kumar',
#   'latitude': 29.9527801,
#   'longitude': 78.0458845,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 19:58:49',
#   'name': 'Sumeet Narula',
#   'latitude': 28.63316487,
#   'longitude': 77.29023844,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 21:06:55',
#   'name': 'Aniketh Kapoor',
#   'latitude': 12.9663201,
#   'longitude': 77.7607219,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/26/2020 21:08:05',
#   'name': 'Vishesh Chopra',
#   'latitude': 12.9645669,
#   'longitude': 77.719023,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 16:05:19',
#   'name': 'Sonu Khan ',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 18:48:08',
#   'name': 'Sachin kumar kathak',
#   'latitude': 28.6389875,
#   'longitude': 77.0809504,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 18:49:01',
#   'name': 'Sachin kumar kathak',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 18:50:53',
#   'name': 'Harsh mehrotra',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 19:01:09',
#   'name': 'Chirag Nagpal',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 20:15:51',
#   'name': 'Nikita Doval',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 21:06:15',
#   'name': 'Sumedha ',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/27/2020 23:30:56',
#   'name': 'Neha Dhookia',
#   'latitude': 22.3157168,
#   'longitude': 87.3053904,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 3:51:13',
#   'name': 'Altaf Sameen',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 7:26:00',
#   'name': 'Yadavindu Ajit',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 13:21:33',
#   'name': 'Kushal Satya',
#   'latitude': 28.5013515,
#   'longitude': 77.0218907,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 13:27:42',
#   'name': 'Jagriti Sikka',
#   'latitude': 28.8878752,
#   'longitude': 76.6318905,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 13:34:40',
#   'name': 'Shaishav Garg',
#   'latitude': 28.5045822,
#   'longitude': 77.0427698,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 13:46:10',
#   'name': 'Archit Patel',
#   'latitude': 21.1654674,
#   'longitude': 72.7911209,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 14:28:18',
#   'name': 'Parul Jauhari',
#   'latitude': 28.5411084,
#   'longitude': 77.3739191,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 14:30:44',
#   'name': 'Shruthi Raghavan',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 14:40:15',
#   'name': 'Anshul Bawa',
#   'latitude': 30.3478987,
#   'longitude': 76.3580756,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 15:17:54',
#   'name': 'Palash R Tatte',
#   'latitude': 28.4637714,
#   'longitude': 77.0808564,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 15:51:58',
#   'name': 'Rajath',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 16:13:06',
#   'name': 'Pranusha Manthri',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 17:29:56',
#   'name': 'Nishant',
#   'latitude': 28.820032,
#   'longitude': 77.5567474,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 18:25:57',
#   'name': 'Sakshi agarwal',
#   'latitude': 12.9727265,
#   'longitude': 77.6310179,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 21:22:29',
#   'name': 'Adityendra Pratap Singh',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/28/2020 23:48:05',
#   'name': 'Divyansh Ameta',
#   'latitude': 28.3901202,
#   'longitude': 76.9561369,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 0:30:13',
#   'name': 'Arjita Bhan',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 1:08:20',
#   'name': 'Subodh Gupta',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 11:30:59',
#   'name': 'Inam Khan',
#   'latitude': 28.39566406,
#   'longitude': 76.95321525,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 12:11:09',
#   'name': 'Mehar Chand ',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 13:29:03',
#   'name': 'Prashant Sharan Srivastava',
#   'latitude': 28.5829916,
#   'longitude': 77.3640137,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 14:00:06',
#   'name': 'Praveen Kumar Sharma',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 16:21:29',
#   'name': 'Dheeraj Joshi',
#   'latitude': 12.9804817,
#   'longitude': 77.63722373,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 17:09:51',
#   'name': 'Giridesh Gupta',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 17:34:49',
#   'name': 'Pranshu Zeesa',
#   'latitude': 26.8573931,
#   'longitude': 75.7900627,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 17:44:05',
#   'name': 'Anand Parameswaran',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 17:49:38',
#   'name': 'Gurbani Walia',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 17:59:42',
#   'name': 'Rupam',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 18:23:36',
#   'name': 'Fathe Singh',
#   'latitude': 26.8579917,
#   'longitude': 75.787896,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 18:46:33',
#   'name': 'GAURAV MALIK',
#   'latitude': 29.1891579,
#   'longitude': 77.1580429,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 21:09:44',
#   'name': 'Ritika Jhanji',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 21:56:01',
#   'name': 'Mandira Nayar',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 23:09:01',
#   'name': 'Komal',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 23:23:39',
#   'name': 'Komal',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/29/2020 23:29:17',
#   'name': 'Ritika Jhanji',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/30/2020 12:06:47',
#   'name': 'Srilakshmi',
#   'latitude': 13.08863603,
#   'longitude': 80.24979729,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/30/2020 14:11:51',
#   'name': 'Gautam Ganesh',
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'},
#  {'timestamp': '3/30/2020 16:44:30',
#   'name': 'Srilakshmi',
#   'latitude': 13.0886444,
#   'longitude': 80.25004633,
#   'radius': 0.5,
#   'icon': 'location',
#   'TYPE': 'VOLUNTEER'}]

# %%
#v_df[['Lat','Lon','Full Name','TYPE']].rename(columns={'Full Name':'name','Lat':'lat','Lon':'lon','TYPE':'type'}).to_json(orient='table',index=False)

#r_df[['Lat','Lon','Full Name','TYPE']].rename(columns={'Full Name':'name','Lat':'lat','Lon':'lon','TYPE':'type'}).to_json(orient='table',index=False)

# %%
# with open('map_config/map_config_public.py','w') as f:
#     f.write('public_live_config = {}'.format(map_1.config))
# with open('map_config/map_config_new.py','r') as f:
#     print(f.read())

# %%
#v_query = ("""Select * from volunteers""")
#v_data = pd.read_sql(v_query,server_con)

#v_df.to_sql(name = 'volunteers', con = engine, schema='thebang7_COVID_SOS', if_exists='append', index = False,index_label=None)

# %%
#Delete command
#ftp.delete(os.path.basename(File2Send))

# %%
# from folium import Map, Marker, GeoJson
# from folium.plugins import MarkerCluster


# v_df

# #quick visualization on map of raw data

# m = Map(location= [12.97194, 77.59369], zoom_start= 12, tiles="cartodbpositron", 
#         attr= '© <a href="http://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors © <a href="http://cartodb.com/attributions#basemaps">CartoDB</a>' 
# )
# mc = MarkerCluster()

# for i in v_df.index:
#     mk = Marker(location=[v_df.loc[i,'Lat'],v_df.loc[i,'Lon']])
#     mk.add_to(mc)
# mc.add_to(m)

# m.save('folium_view.html')
# m
